# %%
#from Aug 11th 2021 to Aug 17th 2021
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Language= ['En', 'Es', 'In', 'Fr', 'Und', 'Th', 'Ja', 'Pt', 'Tl', 'Tr']
Tweet= [4084049,999723,452520,354664,256321,219080, 213996
,164489,66451,65296]
ax.bar(Language, Tweet)
plt.show()
